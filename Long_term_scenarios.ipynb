# %%
import numpy as np

from matplotlib import pyplot as plt

import pandas as pd

# %matplotlib inline

plt.rcParams['figure.figsize'] = (16, 9)

# %%
df_co2 = pd.read_csv("WASP_data_new/WASP_CO2_scenarios.csv", index_col=0).transpose()
df_t = pd.read_csv("WASP_data_new/WASP_T_scenarios.csv", index_col=0).transpose()
df_slr = pd.read_csv("WASP_data_new/WASP_SLR_scenarios.csv", index_col=0).transpose()
df_ph = pd.read_csv("WASP_data_new/WASP_PH_scenarios.csv", index_col=0).transpose()

# %%
plt.rcParams['figure.figsize'] = (16, 9)

# %%
#colors extracted from here: https://twitter.com/NPRougier/status/1323575342204936192/photo/1
ORANGE0 = '#FFF4E6'
ORANGE1 = '#FFE8CC'
ORANGE2 = '#FFD8A8'
ORANGE3 = '#FFC078'
ORANGE4 = '#FFA94D'
ORANGE5 = '#FF922B'
ORANGE6 = '#FD7E14'
ORANGE7 = '#F76707'
ORANGE8 = '#E85900'
ORANGE9 = '#D9480F'
YELLOW0 = '#FFF9DB'
YELLOW1 = '#FFF3BF'
YELLOW2 = '#FFEC99'
YELLOW3 = '#FFE066'
YELLOW4 = '#FFD43B'
YELLOW5 = '#FCC419'
YELLOW6 = '#FAB005'
YELLOW7 = '#F59F00'
YELLOW8 = '#F08000'
YELLOW9 = '#E67700'
LIME0 = '#F4FCE3'
LIME1 = '#E9FAC8'
LIME2 = '#D8F5A2'
LIME3 = '#COEB75'
LIME4 = '#A9E34B'
LIME5 = '#94D82D'
LIME6 = '#82C91E'
LIME7 = '#743816'
LIME8 = '#66A80F'
LIME9 = '#5C940D'
GREEN0 = '#EBFBEE'
GREEN1 = '#D3F9D8'
GREEN2 = '#B2F2BB'
GREEN3 = '#8CE99A'
GREEN4 = '#69DB7C'
GREEN5 = '#51CF66'
GREEN6 = '#40C057'
GREEN7 = '#37B24D'
GREEN8 = '#2F9E44'
GREEN9 = '#2B8A3E'
TEAL0 = '#E6FCF5'
TEAL1 = '#C3FAE8'
TEAL2 = '#96F2D7'
TEAL3 = '#63E6BE'
TEAL4 = '#38D9A9'
TEAL5 = '#20C997'
TEAL6 = '#12B886'
TEAL7 = '#OCA678'
TEAL8 = '#099268'
TEAL9 = '#087F5B'
CYANO = '#E3FAFC'
CYAN1 = '#C5F6FA'
CYAN2 = '#99E9F2'
CYAN3 = '#66D9E8'
CYAN4 = '#3BC9DB'
CYAN5 = '#22B8CF'
CYAN6 = '#15AABF'
CYAN7 = '#1098AD'
CYAN8 = '#0C8599'
CYAN9 = '#0B7285'
BLUE0 = '#E7F5FF'
BLUE1 = '#DOEBFF'
BLUE2 = '#A5D8FF'
BLUE3 = '#74COFC'
BLUE4 = '#4DABF7'
BLUE5 = '#339AFO'
BLUE6 = '#228BE6'
BLUE7 = '#1C7EDO'
BLUE8 = '#1971C2'
BLUE9 = '#1864AB'
INDIGO0 = '#EDF2FF'
INDIGO1 = '#DBE4FF'
INDIGO2 = '#BACOFF'
INDIGO3 = '#91A7EF'
INDIGO4 = '#748FFC'
INDIGO5 = '#5C7CFA'
INDIGO6 = '#4C6EF5'
INDIGO7 = '#4263EB'
INDIGO8 = '#3B5BDB'
INDIGO9 = '#364FC7'
VIOLET0 = '#F3FOFF'
VIOLET1 = '#E5DBFF'
VIOLET2 = '#DOBFFF'
VIOLET3 = '#B197FC'
VIOLET4 = '#9775FA'
VIOLET5 = '#845EF7'
VIOLET6 = '#7950F2'
VIOLET7 = '#7048E8'
VIOLET8 = '#674109'
VIOLET9 = '#5F3DC4'
GRAPE0 = '#F8FOFC'
GRAPE1 = '#F3D9FA'
GRAPE2 = '#EEBEFA'
GRAPE3 = '#E599F7'
GRAPE4 = '#DA77F2'
GRAPE5 = '#CC5DE8'
GRAPE6 = '#BE4BDB'
GRAPE7 = '#AEЗEC9' #fails, misinterpreted as RGBA
GRAPE8 = '#9C36B5'
GRAPE9 = '#862E9C'
PINKO = '#FFF0F6'
PINK1 = '#FFDEEB'
PINK2 = '#FCC2D7'
PINK3 = '#FAA2C1'
PINK4 = '#F783AC'
PINK5 = '#F06595'
PINK6 = '#E64980'
PINK7 = '#D6336C'
PINK8 = '#C2255C'
PINK9 = '#A61E4D'
RED0 = '#FFF5F5'
RED1 = '#FFЕЗЕЗ'
RED2 = '#FFC9C9'
RED3 = '#FFA8A8'
RED4 = '#FF8787'
RED5 = '#FF6B6B'
RED6 = '#FA5252'
RED7 = '#FОЗЕЗЕ' #fails, misinterpreted as RGBA
RED8 = '#E03131'
RED9 = '#C92A2A'
GRAY0 = '#F8F9FA'
GRAY1 = '#F1F3F5'
GRAY2 = '#E9ECEF'
GRAY3 = '#DEE2E6'
GRAY4 = '#CED4DA'
GRAY5 = '#ADB5BD'
GRAY6 = '#868E96'
GRAY7 = '#495057'
GRAY8 = '#343A40'
GRAY9 = '#212529'

# %%
plot_dict = {'ssp119_zeroed':(GREEN9,'-'),
             'ssp119_2GtC_373':(GREEN7,'-'),
             'ssp119_4GtC_373':(GREEN5,'-'),
             'ssp119_6GtC_373':(GREEN3,'-'),
#              'ssp119':('gray','-'),
#             'ssp126_zeroed':(BLUE9,'-'),
#              'ssp126_2GtC_373':(CYAN7,'-'),
#              'ssp126_4GtC_373':(CYAN5,'-'),
#              'ssp126_6GtC_373':(CYAN3,'-'),
#              'ssp126':('gray','-'),
             'ssp434_zeroed':(INDIGO9,'-'),
              'ssp434_2GtC_373':(INDIGO7,'-'),
              'ssp434_4GtC_373':(INDIGO5,'-'),
              'ssp434_6GtC_373':(INDIGO3,'-'),
#              'ssp434':('gray','-'),
            'ssp245_zeroed':(PINK9,'-'),
             'ssp245_2GtC_373':(PINK7,'-'),
             'ssp245_4GtC_373':(PINK5,'-'),
             'ssp245_6GtC_373':(PINK3,'-'),
#              'ssp245':('gray','-'),
#              'ssp460_zeroed':(ORANGE9,'-'),
#              'ssp460_2GtC_373':(ORANGE7,'-'),
#              'ssp460_4GtC_373':(ORANGE5,'-'),
#              'ssp460_6GtC_373':(ORANGE3,'-'),
#              'ssp460':('gray','-'),
             'ssp119_zeroed_SolarGeo15':(GREEN9,'--'),
             'ssp119_2GtC_373_SolarGeo15':(GREEN7,'--'),
             'ssp119_4GtC_373_SolarGeo15':(GREEN5,'--'),
             'ssp119_6GtC_373_SolarGeo15':(GREEN3,'--'),
#              'ssp119_SolarGeo15':('gray','--'),
#             'ssp126_zeroed_SolarGeo15':(BLUE9,'--'),
#              'ssp126_2GtC_373_SolarGeo15':(CYAN7,'--'),
#              'ssp126_4GtC_373_SolarGeo15':(CYAN5,'--'),
#              'ssp126_6GtC_373_SolarGeo15':(CYAN3,'--'),
#              'ssp126_SolarGeo15':('gray','--'),
             'ssp434_zeroed_SolarGeo15':(INDIGO9,'--'),
              'ssp434_2GtC_373_SolarGeo15':(INDIGO7,'--'),
              'ssp434_4GtC_373_SolarGeo15':(INDIGO5,'--'),
              'ssp434_6GtC_373_SolarGeo15':(INDIGO3,'--'),
#              'ssp434_SolarGeo15':('gray','--'),
             'ssp245_zeroed_SolarGeo15':(PINK9,'--'),
              'ssp245_2GtC_373_SolarGeo15':(PINK7,'--'),
              'ssp245_4GtC_373_SolarGeo15':(PINK5,'--'),
              'ssp245_6GtC_373_SolarGeo15':(PINK3,'--'),
#              'ssp245_SolarGeo15':('gray','--'),
#              'ssp460_zeroed_SolarGeo15':(ORANGE9,'--'),
#              'ssp460_2GtC_373_SolarGeo15':(ORANGE7,'--'),
#              'ssp460_4GtC_373_SolarGeo15':(ORANGE5,'--'),
#              'ssp460_6GtC_373_SolarGeo15':(ORANGE3,'--'),
             #'ssp460_SolarGeo15':('gray','--'),
            }

fig, ax = plt.subplots(nrows=2, ncols=2)

ax[0,0].title.set_text("Global CO2")
ax[0,1].title.set_text("Global Temperature")
ax[1,0].title.set_text("Global Surface Ocean PH")
ax[1,1].title.set_text("Global Sea Level")

ax[0,0].set_ylabel("CO2 Concentration (ppmv)")
ax[0,1].set_ylabel("Temperature Change (K)")
ax[1,0].set_ylabel("Surface Ocean pH")
ax[1,1].set_ylabel("Sea Level Change (m)")

xticks = [100,150,250,350,450,550,650] # [50,150,250,350,450,550,650]
xtick_labels = ['1950','2000','2100','2200','2300','2400','2500'] # ['1900','2000','2100','2200','2300','2400','2500']

ax[0,0].set_xticks(xticks)
ax[0,1].set_xticks(xticks)
ax[1,0].set_xticks(xticks)
ax[1,1].set_xticks(xticks)

ax[0,0].set_xticklabels(xtick_labels)
ax[0,1].set_xticklabels(xtick_labels)
ax[1,0].set_xticklabels(xtick_labels)
ax[1,1].set_xticklabels(xtick_labels)

ax[0,0].set_xlim([100,450]) #([0,450])
ax[0,1].set_xlim([100,450])
ax[1,0].set_xlim([100,450])
ax[1,1].set_xlim([100,450])

ax[1,1].set_ylim([-0.2,2.0])

for scen in plot_dict.keys(): 

    df_co2[scen].plot(color=plot_dict[scen][0], linestyle=plot_dict[scen][1], ax=ax[0,0])
    df_t[scen].rolling(window=10).mean().plot(color=plot_dict[scen][0], linestyle=plot_dict[scen][1], ax=ax[0,1])
    df_ph[scen].plot(color=plot_dict[scen][0], linestyle=plot_dict[scen][1], ax=ax[1,0])
    df_slr[scen].plot(color=plot_dict[scen][0], linestyle=plot_dict[scen][1], ax=ax[1,1])
    
ax[0,1].axhline(1.5, color='k')

# ax[1,1].legend()

# %%
plot_dict = {#'ssp119_zeroed':(GREEN9,'-'),
#              'ssp119_2GtC_373':(GREEN7,'-'),
#              'ssp119_4GtC_373':(GREEN5,'-'),
#              'ssp119_6GtC_373':(GREEN3,'-'),
# #              #'ssp119':('gray','-'),
# #              'ssp126_zeroed':(CYAN9,'-'),
# #              'ssp126_2GtC_373':(CYAN7,'-'),
# #              'ssp126_4GtC_373':(CYAN5,'-'),
# #              'ssp126_6GtC_373':(CYAN3,'-'),
#              #'ssp126':('gray','-'),
#              'ssp434_zeroed':(INDIGO9,'-'),
#              'ssp434_2GtC_373':(INDIGO7,'-'),
#              'ssp434_4GtC_373':(INDIGO5,'-'),
#              'ssp434_6GtC_373':(INDIGO3,'-'),
#              #'ssp434':('gray','-'),
#              'ssp245_zeroed':(PINK9,'-'),
#              'ssp245_2GtC_373':(PINK7,'-'),
#              'ssp245_4GtC_373':(PINK5,'-'),
#              'ssp245_6GtC_373':(PINK3,'-'),
#              #'ssp245':('gray','-'),
#              'ssp460_zeroed':(ORANGE9,'-'),
#              'ssp460_2GtC_373':(ORANGE7,'-'),
#              'ssp460_4GtC_373':(ORANGE5,'-'),
#              'ssp460_6GtC_373':(ORANGE3,'-'),
             #'ssp460':('gray','--'),
#              'ssp126_zeroed_SolarGeo15':(CYAN9,'--'),
#              'ssp126_2GtC_373_SolarGeo15':(CYAN7,'--'),
#              'ssp126_4GtC_373_SolarGeo15':(CYAN5,'--'),
#              'ssp126_6GtC_373_SolarGeo15':(CYAN3,'--'),
             #'ssp126_SolarGeo15':('gray','--'),
             'ssp434_zeroed_SolarGeo15':(INDIGO9,'--'),
             'ssp434_2GtC_373_SolarGeo15':(INDIGO7,'--'),
             'ssp434_4GtC_373_SolarGeo15':(INDIGO5,'--'),
             'ssp434_6GtC_373_SolarGeo15':(INDIGO3,'--'),
             #'ssp434_SolarGeo15':('gray','--'),
             'ssp245_zeroed_SolarGeo15':(PINK9,'--'),
             'ssp245_2GtC_373_SolarGeo15':(PINK7,'--'),
             'ssp245_4GtC_373_SolarGeo15':(PINK5,'--'),
             'ssp245_6GtC_373_SolarGeo15':(PINK3,'--'),
             #'ssp245_SolarGeo15':('gray','--'),
             'ssp460_zeroed_SolarGeo15':(ORANGE9,'--'),
             'ssp460_2GtC_373_SolarGeo15':(ORANGE7,'--'),
             'ssp460_4GtC_373_SolarGeo15':(ORANGE5,'--'),
             'ssp460_6GtC_373_SolarGeo15':(ORANGE3,'--'),
             #'ssp460_SolarGeo15':('gray','--'),
            }

fig, ax = plt.subplots(nrows=2, ncols=2)

ax[0,0].title.set_text("Global CO2")
ax[0,1].title.set_text("Global Temperature")
ax[1,0].title.set_text("Global Surface Ocean PH")
ax[1,1].title.set_text("Global Sea Level")

ax[0,0].set_ylabel("CO2 Concentration (ppmv)")
ax[0,1].set_ylabel("Temperature Change (K)")
ax[1,0].set_ylabel("Surface Ocean pH")
ax[1,1].set_ylabel("Sea Level Change (m)")

ax[0,0].set_xticks(xticks)
ax[0,1].set_xticks(xticks)
ax[1,0].set_xticks(xticks)
ax[1,1].set_xticks(xticks)

ax[0,0].set_xticklabels(xtick_labels)
ax[0,1].set_xticklabels(xtick_labels)
ax[1,0].set_xticklabels(xtick_labels)
ax[1,1].set_xticklabels(xtick_labels)

ax[0,0].set_xlim([0,450])
ax[0,1].set_xlim([0,450])
ax[1,0].set_xlim([0,450])
ax[1,1].set_xlim([0,450])

ax[1,1].set_ylim([-0.2,2.0])

for scen in plot_dict.keys(): 

    df_co2[scen].plot(color=plot_dict[scen][0], linestyle=plot_dict[scen][1], ax=ax[0,0])
    df_t[scen].rolling(window=10).mean().plot(color=plot_dict[scen][0], linestyle=plot_dict[scen][1], ax=ax[0,1])
    df_ph[scen].plot(color=plot_dict[scen][0], linestyle=plot_dict[scen][1], ax=ax[1,0])
    df_slr[scen].plot(color=plot_dict[scen][0], linestyle=plot_dict[scen][1], ax=ax[1,1])

# %%
"""
Figure for comment. Plot extensions vs. our extensions
"""

"""
Figure for Plan A+ talk
"""


# import matplotlib
# font = {'size'   : 15}

# matplotlib.rc('font', **font)

plot_dict = {#'ssp119_zeroed':(GREEN9,'-'),
             #'ssp119_2GtC_373':(GREEN7,'-'),
             #'ssp119_4GtC_373':(GREEN5,'-'),
             #'ssp119_6GtC_373':(GREEN3,'-'),
#              'ssp119':('gray','-'),
#             'ssp126_zeroed':(BLUE9,'-'),
#              'ssp126_2GtC_373':(CYAN7,'-'),
#              'ssp126_4GtC_373':(CYAN5,'-'),
#              'ssp126_6GtC_373':(CYAN3,'-'),
#              'ssp126':('gray','-'),
             'ssp434_zeroed':(INDIGO9,'-'),
#               'ssp434_2GtC_373':(INDIGO7,'-'),
#               'ssp434_4GtC_373':(INDIGO5,'-'),
              'ssp434_6GtC_373':(INDIGO3,'-'),
#              'ssp434':('gray','-'),
#             'ssp245_zeroed':(PINK9,'-'),
#              'ssp245_2GtC_373':(PINK7,'-'),
#              'ssp245_4GtC_373':(PINK5,'-'),
#              'ssp245_6GtC_373':(PINK3,'-'),
#              'ssp245':('gray','-'),
#              'ssp460_zeroed':(ORANGE9,'-'),
#              'ssp460_2GtC_373':(ORANGE7,'-'),
#              'ssp460_4GtC_373':(ORANGE5,'-'),
#              'ssp460_6GtC_373':(ORANGE3,'-'),
#              'ssp460':('gray','-'),
#              'ssp119_zeroed_SolarGeo15':(GREEN9,'--'),
#              'ssp119_2GtC_373_SolarGeo15':(GREEN7,'--'),
#              'ssp119_4GtC_373_SolarGeo15':(GREEN5,'--'),
#              'ssp119_6GtC_373_SolarGeo15':(GREEN3,'--'),
#              'ssp119_SolarGeo15':('gray','--'),
#             'ssp126_zeroed_SolarGeo15':(BLUE9,'--'),
#              'ssp126_2GtC_373_SolarGeo15':(CYAN7,'--'),
#              'ssp126_4GtC_373_SolarGeo15':(CYAN5,'--'),
#              'ssp126_6GtC_373_SolarGeo15':(CYAN3,'--'),
#              'ssp126_SolarGeo15':('gray','--'),
#              'ssp434_zeroed_SolarGeo15':(INDIGO9,'--'),
#               'ssp434_2GtC_373_SolarGeo15':(INDIGO7,'--'),
#               'ssp434_4GtC_373_SolarGeo15':(INDIGO5,'--'),
#               'ssp434_6GtC_373_SolarGeo15':(INDIGO3,'--'),
#              'ssp434_SolarGeo15':('gray','--'),
#              'ssp245_zeroed_SolarGeo15':(PINK9,'--'),
#               'ssp245_2GtC_373_SolarGeo15':(PINK7,'--'),
#               'ssp245_4GtC_373_SolarGeo15':(PINK5,'--'),
#               'ssp245_6GtC_373_SolarGeo15':(PINK3,'--'),
#              'ssp245_SolarGeo15':('gray','--'),
#              'ssp460_zeroed_SolarGeo15':(ORANGE9,'--'),
#              'ssp460_2GtC_373_SolarGeo15':(ORANGE7,'--'),
#              'ssp460_4GtC_373_SolarGeo15':(ORANGE5,'--'),
#              'ssp460_6GtC_373_SolarGeo15':(ORANGE3,'--'),
             #'ssp460_SolarGeo15':('gray','--'),
            }

fig, ax = plt.subplots(nrows=2, ncols=2)

ax[0,0].title.set_text("Global CO2")
ax[0,1].title.set_text("Global Temperature")
ax[1,0].title.set_text("Global Surface Ocean PH")
ax[1,1].title.set_text("Global Sea Level")

ax[0,0].set_ylabel("CO2 Concentration (ppmv)")
ax[0,1].set_ylabel("Temperature Change (K)")
ax[1,0].set_ylabel("Surface Ocean pH")
ax[1,1].set_ylabel("Sea Level Change (m)")

xticks = [100,150,200,250,300,350,450,550,650] # [50,150,250,350,450,550,650]
xtick_labels = ['1950','2000','2050','2100','2150','2200','2300','2400','2500'] # ['1900','2000','2100','2200','2300','2400','2500']

ax[0,0].set_xticks(xticks)
ax[0,1].set_xticks(xticks)
ax[1,0].set_xticks(xticks)
ax[1,1].set_xticks(xticks)

ax[0,0].set_xticklabels(xtick_labels)
ax[0,1].set_xticklabels(xtick_labels)
ax[1,0].set_xticklabels(xtick_labels)
ax[1,1].set_xticklabels(xtick_labels)

ax[0,0].set_xlim([100,400]) #([0,450])
ax[0,1].set_xlim([100,400])
ax[1,0].set_xlim([100,400])
ax[1,1].set_xlim([100,400])

ax[1,1].set_ylim([-0.2,1.5])
ax[0,1].set_ylim([0,2.6])
ax[0,0].set_ylim([300,485])

for scen in plot_dict.keys(): 

    df_co2[scen].plot(color=plot_dict[scen][0], linestyle=plot_dict[scen][1], ax=ax[0,0],linewidth=3)
    df_t[scen].rolling(window=10).mean().plot(color=plot_dict[scen][0], linestyle=plot_dict[scen][1], ax=ax[0,1],linewidth=3)
    df_ph[scen].plot(color=plot_dict[scen][0], linestyle=plot_dict[scen][1], ax=ax[1,0],linewidth=3)
    df_slr[scen].plot(color=plot_dict[scen][0], linestyle=plot_dict[scen][1], ax=ax[1,1],linewidth=3)
    
# ax[0,1].axhline(1.5, color='k')

# ax[1,1].legend()

plt.savefig('foo.png')

# %%
"""
Figure for comment. Plot extensions vs. our extensions
"""

"""
Figure for Plan A+ talk
"""


# import matplotlib
# font = {'size'   : 15}

# matplotlib.rc('font', **font)

plot_dict = {#'ssp119_zeroed':(GREEN9,'-'),
             #'ssp119_2GtC_373':(GREEN7,'-'),
             #'ssp119_4GtC_373':(GREEN5,'-'),
             #'ssp119_6GtC_373':(GREEN3,'-'),
#              'ssp119':('gray','-'),
#             'ssp126_zeroed':(BLUE9,'-'),
#              'ssp126_2GtC_373':(CYAN7,'-'),
#              'ssp126_4GtC_373':(CYAN5,'-'),
#              'ssp126_6GtC_373':(CYAN3,'-'),
#              'ssp126':('gray','-'),
             'ssp434_zeroed':(INDIGO9,'-'),
#               'ssp434_2GtC_373':(INDIGO7,'-'),
#               'ssp434_4GtC_373':(INDIGO5,'-'),
              'ssp434_6GtC_373':(INDIGO3,'-'),
#              'ssp434':('gray','-'),
#             'ssp245_zeroed':(PINK9,'-'),
#              'ssp245_2GtC_373':(PINK7,'-'),
#              'ssp245_4GtC_373':(PINK5,'-'),
#              'ssp245_6GtC_373':(PINK3,'-'),
#              'ssp245':('gray','-'),
#              'ssp460_zeroed':(ORANGE9,'-'),
#              'ssp460_2GtC_373':(ORANGE7,'-'),
#              'ssp460_4GtC_373':(ORANGE5,'-'),
#              'ssp460_6GtC_373':(ORANGE3,'-'),
#              'ssp460':('gray','-'),
#              'ssp119_zeroed_SolarGeo15':(GREEN9,'--'),
#              'ssp119_2GtC_373_SolarGeo15':(GREEN7,'--'),
#              'ssp119_4GtC_373_SolarGeo15':(GREEN5,'--'),
#              'ssp119_6GtC_373_SolarGeo15':(GREEN3,'--'),
#              'ssp119_SolarGeo15':('gray','--'),
#             'ssp126_zeroed_SolarGeo15':(BLUE9,'--'),
#              'ssp126_2GtC_373_SolarGeo15':(CYAN7,'--'),
#              'ssp126_4GtC_373_SolarGeo15':(CYAN5,'--'),
#              'ssp126_6GtC_373_SolarGeo15':(CYAN3,'--'),
#              'ssp126_SolarGeo15':('gray','--'),
             'ssp434_zeroed_SolarGeo15':(INDIGO9,'--'),
#               'ssp434_2GtC_373_SolarGeo15':(INDIGO7,'--'),
#               'ssp434_4GtC_373_SolarGeo15':(INDIGO5,'--'),
              'ssp434_6GtC_373_SolarGeo15':(INDIGO3,'--'),
#              'ssp434_SolarGeo15':('gray','--'),
#              'ssp245_zeroed_SolarGeo15':(PINK9,'--'),
#               'ssp245_2GtC_373_SolarGeo15':(PINK7,'--'),
#               'ssp245_4GtC_373_SolarGeo15':(PINK5,'--'),
#               'ssp245_6GtC_373_SolarGeo15':(PINK3,'--'),
#              'ssp245_SolarGeo15':('gray','--'),
#              'ssp460_zeroed_SolarGeo15':(ORANGE9,'--'),
#              'ssp460_2GtC_373_SolarGeo15':(ORANGE7,'--'),
#              'ssp460_4GtC_373_SolarGeo15':(ORANGE5,'--'),
#              'ssp460_6GtC_373_SolarGeo15':(ORANGE3,'--'),
             #'ssp460_SolarGeo15':('gray','--'),
            }

fig, ax = plt.subplots(nrows=2, ncols=2)

ax[0,0].title.set_text("Global Temperature")
ax[0,1].title.set_text("Global Precip (illustrative)")

ax[0,0].set_ylabel("Temperature Change (K)")
ax[0,1].set_ylabel("Precipitation (illustrative)")

xticks = [100,150,200,250,300,350,450,550,650] # [50,150,250,350,450,550,650]
xtick_labels = ['1950','2000','2050','2100','2150','2200','2300','2400','2500'] # ['1900','2000','2100','2200','2300','2400','2500']

ax[0,0].set_xticks(xticks)
ax[0,1].set_xticks(xticks)

ax[0,0].set_xticklabels(xtick_labels)
ax[0,1].set_xticklabels(xtick_labels)


ax[0,0].set_xlim([100,400]) #([0,450])
ax[0,1].set_xlim([100,400])

# ax[1,1].set_ylim([-0.2,1.5])
# ax[0,1].set_ylim([0,2.6])
# ax[0,0].set_ylim([300,485])

for scen in plot_dict.keys(): 
    df_t[scen].rolling(window=10).mean().plot(color=plot_dict[scen][0], linestyle=plot_dict[scen][1], ax=ax[0,0],linewidth=3)
    
scen = 'ssp434_zeroed'
df_t[scen].rolling(window=10).mean().plot(color=plot_dict[scen][0], linestyle=plot_dict[scen][1], ax=ax[0,1],linewidth=3)
scen = 'ssp434_6GtC_373'
df_t[scen].rolling(window=10).mean().plot(color=plot_dict[scen][0], linestyle=plot_dict[scen][1], ax=ax[0,1],linewidth=3)

scen = 'ssp434_zeroed_SolarGeo15'
data = df_t['ssp434_zeroed'].rolling(window=10).mean() - 1.5 * (df_t['ssp434_zeroed'].rolling(window=10).mean() - df_t[scen].rolling(window=10).mean())
data.plot(color=plot_dict[scen][0], linestyle=plot_dict[scen][1], ax=ax[0,1],linewidth=3)
scen = 'ssp434_6GtC_373_SolarGeo15'
data = df_t['ssp434_6GtC_373'].rolling(window=10).mean() - 1.5 * (df_t['ssp434_6GtC_373'].rolling(window=10).mean() - df_t[scen].rolling(window=10).mean())
data.plot(color=plot_dict[scen][0], linestyle=plot_dict[scen][1], ax=ax[0,1],linewidth=3)
# ax[0,1].axhline(1.5, color='k')

# ax[1,1].legend()

plt.savefig('foo.png')
